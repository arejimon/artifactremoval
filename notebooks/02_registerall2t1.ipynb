# %%
import logging
from pathlib import Path

from artifactremoval.registration import batch_process_registration
from artifactremoval.midas import MidasProject

# %%
# Get the base directory where the app.py file is located
base_dir = Path.cwd().parent

# Read from raw to ensure registration and T1 are aligned to SIREF
project_dir = base_dir / "data" / "raw" / "MIDAS_ArtifactRemoval"
interim_directory = project_dir.parents[1] / "interim"
project_file = project_dir / f"{project_dir.name}_project.xml"

# ---------------------------------------------------------------------
# Logging Configuration
# ---------------------------------------------------------------------
log_file = interim_directory / "02_registration_logfile.log"
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler(log_file, mode="w"),
        logging.StreamHandler()
    ]
)

# Load your project (assuming MidasProject is defined elsewhere)
project = MidasProject(project_file)

# Run batch processing
batch_process_registration(project, interim_directory, overwrite = True)

logging.shutdown()
# Out:
# 2025-02-13 14:50:36,970 - INFO - Found 59 subjects to process.
# 2025-02-13 14:50:36,971 - INFO -
# === Processing Subject: DOSEESC_EM01 ===
# 2025-02-13 14:50:37,016 - INFO - Processing Subject DOSEESC_EM01 - Study 09/20/2017
# 2025-02-13 14:50:37,187 - INFO - 	Successfully loaded unprocessed_t1.nii.gz
# 2025-02-13 14:50:37,260 - INFO - 	Successfully loaded unprocessed_flair.nii.gz
# 2025-02-13 14:50:37,299 - INFO - 	Successfully loaded unprocessed_siref.nii.gz
# 2025-02-13 14:50:37,312 - INFO - 	Successfully loaded unprocessed_brainmask.nii.gz
# 2025-02-13 14:50:37,313 - INFO - 	Size of T1: (256, 256, 160)
# 2025-02-13 14:50:39,017 - INFO - 	New SIREF Size: (256, 256, 160)
# 2025-02-13 14:50:39,036 - INFO - 	New Brain Mask Size: (256, 256, 160)
# 2025-02-13 14:50:40,104 - INFO - 	New FLAIR Size: (256, 256, 160)
# 2025-02-13 14:50:41,083 - INFO - 	Saved T1
# 2025-02-13 14:50:42,786 - INFO - 	Saved SIREF
# 2025-02-13 14:50:42,860 - INFO - 	Saved Brain Mask
# ...
