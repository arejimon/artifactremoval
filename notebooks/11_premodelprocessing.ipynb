# %%
from artifactremoval.premodelprocessing import *
from pathlib import Path 

import numpy as np
from sklearn.model_selection import train_test_split, GroupShuffleSplit
import datetime as dt

# %%
## CHANGE THESE DIRECTORIES WHEN THE TIME COMES

base_dir = Path.cwd().parent
input_dir = base_dir / "data" / "ratings" / "individual_csv"
output_dir = base_dir / "data" / "ratings" / "aggregate_data"

input_spectral_data_dir = base_dir / "data" / "processed" / '20250411_202222'
input_spectral_file = input_spectral_data_dir / "unique_ids_group_25_20250411_202222_raters.pkl"

output_aggregated_csv_file = output_dir / "aggregated_spectral_ratings.csv"

log_file = Path("11v4_premodelprocessing.log")
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler(str(log_file), mode="w"),
        logging.StreamHandler()
    ]
)

# %%
csv_files = list(input_dir.glob("*.csv"))
csv_files = [str(file) for file in csv_files]

logging.info(f"CSV files found: {csv_files}")

logging.info("Cleaning 'Poor Quality' labels in individual CSVs…")

for file in csv_files:
    df = pd.read_csv(file)
    # Count how many ‘Poor Quality’ entries
    num_poor = (df['rating'] == "Poor Quality").sum()
    if num_poor > 0:
        logging.warning(f"{num_poor} 'Poor Quality' labels found in {file}; recoding to 'Unacceptable'")
        df['rating'] = df['rating'].replace("Poor Quality", "Unacceptable")
        # Save back to the same CSV
        df.to_csv(file, index=False)
        logging.info(f"Saved cleaned CSV: {file}")
    else:
        logging.info(f"No 'Poor Quality' labels in {file}")

# Read and concatenate all CSV files into one DataFrame.
df_list = [pd.read_csv(file) for file in csv_files]
all_ratings_df = pd.concat(df_list, ignore_index=True)
logging.info("Combined CSV file preview:")
logging.info("\n" + all_ratings_df.head().to_string())

# --------------------------------------
# Step 2: Aggregate Ratings
# --------------------------------------
aggregated_df = all_ratings_df.groupby('unique_id')\
    .apply(aggregate_ratings)\
    .reset_index()
logging.info("Aggregated Ratings (first few rows):")
logging.info("\n" + aggregated_df.head().to_string())

# --------------------------------------
# Step 2.1: Recode any 'Poor Quality' → 'Unacceptable' in consensus
# --------------------------------------
num_poor = (aggregated_df['consensus'] == "Poor Quality").sum()
if num_poor > 0:
    logging.warning(f"Found {num_poor} ‘Poor Quality’ consensus labels; recoding to 'Unacceptable'")
    aggregated_df['consensus'] = aggregated_df['consensus'].replace("Poor Quality", "Unacceptable")
else:
    logging.info("No 'Poor Quality' consensus labels found.")

# --------------------------------------
# Step 2.2: Export the cleaned, aggregated data
# --------------------------------------
aggregated_df.to_csv(output_aggregated_csv_file, index=False)
logging.info(f"Aggregated spectral ratings saved to '{output_aggregated_csv_file}'")

# --------------------------------------
# Step 3: Verification of the Aggregation
# --------------------------------------
inconsistencies = verify_aggregates(aggregated_df, all_ratings_df)
if not inconsistencies:
    logging.info("Verification succeeded: All aggregated ratings match the individual CSV data.")
else:
    logging.error("Inconsistencies found:")
    for inc in inconsistencies:
        logging.error(inc)
# Out:
# 2025-04-23 16:40:04,879 - INFO - CSV files found: ['x:\\ArtifactRemovalProject\\data\\ratings\\individual_csv\\unique_ids_group_25_20250411_202222_raters_completed_Maudsley.csv', 'x:\\ArtifactRemovalProject\\data\\ratings\\individual_csv\\unique_ids_group_25_20250411_202222_raters_completed_Mellon.csv', 'x:\\ArtifactRemovalProject\\data\\ratings\\individual_csv\\unique_ids_group_25_20250411_202222_raters_completed_Poptani.csv', 'x:\\ArtifactRemovalProject\\data\\ratings\\individual_csv\\unique_ids_group_25_20250411_202222_raters_completed_Sheriff.csv', 'x:\\ArtifactRemovalProject\\data\\ratings\\individual_csv\\unique_ids_group_25_20250411_202222_raters_completed_Shim.csv', 'x:\\ArtifactRemovalProject\\data\\ratings\\individual_csv\\unique_ids_group_25_20250411_202222_raters_completed_Shu.csv', 'x:\\ArtifactRemovalProject\\data\\ratings\\individual_csv\\unique_ids_group_25_20250411_202222_raters_completed_Soher.csv', 'x:\\ArtifactRemovalProject\\data\\ratings\\individual_csv\\unique_ids_group_25_20250411_202222_raters_completed_Weinberg.csv']
# 2025-04-23 16:40:04,881 - INFO - Cleaning 'Poor Quality' labels in individual CSVs…
# 2025-04-23 16:40:04,953 - INFO - No 'Poor Quality' labels in x:\ArtifactRemovalProject\data\ratings\individual_csv\unique_ids_group_25_20250411_202222_raters_completed_Maudsley.csv
# 2025-04-23 16:40:04,993 - INFO - No 'Poor Quality' labels in x:\ArtifactRemovalProject\data\ratings\individual_csv\unique_ids_group_25_20250411_202222_raters_completed_Mellon.csv
# 2025-04-23 16:40:05,062 - INFO - No 'Poor Quality' labels in x:\ArtifactRemovalProject\data\ratings\individual_csv\unique_ids_group_25_20250411_202222_raters_completed_Poptani.csv
# 2025-04-23 16:40:05,081 - INFO - No 'Poor Quality' labels in x:\ArtifactRemovalProject\data\ratings\individual_csv\unique_ids_group_25_20250411_202222_raters_completed_Sheriff.csv
# 2025-04-23 16:40:05,104 - WARNING - 3 'Poor Quality' labels found in x:\ArtifactRemovalProject\data\ratings\individual_csv\unique_ids_group_25_20250411_202222_raters_completed_Shim.csv; recoding to 'Unacceptable'
# 2025-04-23 16:40:05,136 - INFO - Saved cleaned CSV: x:\ArtifactRemovalProject\data\ratings\individual_csv\unique_ids_group_25_20250411_202222_raters_completed_Shim.csv
# 2025-04-23 16:40:05,308 - INFO - No 'Poor Quality' labels in x:\ArtifactRemovalProject\data\ratings\individual_csv\unique_ids_group_25_20250411_202222_raters_completed_Shu.csv
# 2025-04-23 16:40:05,349 - INFO - No 'Poor Quality' labels in x:\ArtifactRemovalProject\data\ratings\individual_csv\unique_ids_group_25_20250411_202222_raters_completed_Soher.csv
# 2025-04-23 16:40:05,391 - INFO - No 'Poor Quality' labels in x:\ArtifactRemovalProject\data\ratings\individual_csv\unique_ids_group_25_20250411_202222_raters_completed_Weinberg.csv
# 2025-04-23 16:40:05,443 - INFO - Combined CSV file preview:
# 2025-04-23 16:40:05,446 - INFO -
#               name                         unique_id        rating              time completed  time taken
# 0  Andrew Maudsley   DOSEESC_EM01_10.16.2017_9_24_27  Unacceptable  2025-04-19T22:29:31.437760   29.766863
# 1  Andrew Maudsley  DOSEESC_EM12_01.25.2019_11_45_35    Acceptable  2025-04-19T22:29:41.097481    8.616255
# 2  Andrew Maudsley  DOSEESC_JH10_12.28.2018_22_33_37    Acceptable  2025-04-19T22:29:48.189469    6.050606
# 3  Andrew Maudsley   DOSEESC_EM08_11.02.2018_8_51_37  Unacceptable  2025-04-19T22:30:02.484220   13.182644
# 4  Andrew Maudsley  DOSEESC_UM18_01.23.2019_17_41_42    Acceptable  2025-04-19T22:30:10.451956    6.844780
# C:\Users\VHUANG9\AppData\Local\Temp\ipykernel_21840\4143339986.py:30: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   aggregated_df = all_ratings_df.groupby('unique_id')\
# 2025-04-23 16:40:06,416 - INFO - Aggregated Ratings (first few rows):
# 2025-04-23 16:40:06,419 - INFO -
#                           unique_id      rating_1      rating_2      rating_3     consensus                                            raters
# 0  DOSEESC_EM01_09.20.2017_10_18_34    Acceptable    Acceptable    Acceptable    Acceptable        [Harish Poptani, Hui-Kuo Shu, Brian Soher]
# 1  DOSEESC_EM01_09.20.2017_10_21_33    Acceptable  Unacceptable    Acceptable    Acceptable        [Harish Poptani, Hui-Kuo Shu, Brian Soher]
# 2  DOSEESC_EM01_09.20.2017_10_23_23    Acceptable    Acceptable    Acceptable    Acceptable      [Andrew Maudsley, Eric Mellon, Hyunsuk Shim]
# 3  DOSEESC_EM01_09.20.2017_10_26_26  Unacceptable    Acceptable  Unacceptable  Unacceptable  [Sulaiman Sheriff, Hyunsuk Shim, Brent Weinberg]
# 4  DOSEESC_EM01_09.20.2017_10_31_23    Acceptable    Acceptable    Acceptable    Acceptable      [Andrew Maudsley, Eric Mellon, Hyunsuk Shim]
# 2025-04-23 16:40:06,420 - INFO - No 'Poor Quality' consensus labels found.
# 2025-04-23 16:40:06,480 - INFO - Aggregated spectral ratings saved to 'x:\ArtifactRemovalProject\data\ratings\aggregate_data\aggregated_spectral_ratings.csv'
# 2025-04-23 16:40:06,481 - INFO - Starting verification of aggregated ratings.
# 2025-04-23 16:40:12,037 - INFO - Verification succeeded: All aggregated ratings match the original CSV data.
# 2025-04-23 16:40:12,038 - INFO - Verification succeeded: All aggregated ratings match the individual CSV data.

# %%
# Step 1: Load spectral data.
spectral_data = load_spectral_data(input_spectral_file)
aggregated_csv_file = output_aggregated_csv_file

# Step 2: Load aggregated CSV data.
logging.info(f"Loading aggregated CSV data from: {aggregated_csv_file}")
aggregated_df = pd.read_csv(aggregated_csv_file)
logging.info(f"Aggregated CSV loaded with {len(aggregated_df)} rows.")

# Step 3: Create a consensus mapping from the aggregated CSV.
consensus_mapping = aggregated_df.set_index('unique_id')['consensus'].to_dict()
logging.info("Consensus mapping created successfully.")

# Step 4: Update spectral data with consensus ratings.
spectral_data = update_spectral_data_with_consensus(spectral_data, consensus_mapping)

# Step 5: Verification - Display 10 random entries.
display_random_consensus_entries(spectral_data, aggregated_df, sample_size=10)

subject_ids = [extract_subject_id(rec["unique_id"]) for rec in spectral_data]

# ----- 2.  Build X, y, groups for the splitter -------------------
X  = np.arange(len(spectral_data))                 # indices only
y  = [rec["consensus_rating"] for rec in spectral_data]   # labels for stratification
g  = subject_ids                                   # group identifier

# ----- 3.  Group-stratified split (20 % test) --------------------
gss = GroupShuffleSplit(test_size=0.10, n_splits=1, random_state=42)
train_idx, test_idx = next(gss.split(X, y, groups=g))

train_data = [spectral_data[i] for i in train_idx]
test_data  = [spectral_data[i] for i in test_idx]

train_data_filtered = [e for e in train_data if e.get("consensus_rating") is not None]
test_data_filtered = [e for e in test_data if e.get("consensus_rating") is not None]

logging.info(f"Reserved {len(test_data_filtered)} / {len(spectral_data)} entries "
             f"({len(test_idx)/len(spectral_data):.1%}) for the test set.")
# Out:
# 2025-04-23 16:40:12,061 - INFO - Loading spectral data from pickle file: x:\ArtifactRemovalProject\data\processed\20250411_202222\unique_ids_group_25_20250411_202222_raters.pkl
# 2025-04-23 16:40:12,518 - INFO - Spectral data loaded successfully.
# 2025-04-23 16:40:12,520 - INFO - Loading aggregated CSV data from: x:\ArtifactRemovalProject\data\ratings\aggregate_data\aggregated_spectral_ratings.csv
# 2025-04-23 16:40:12,548 - INFO - Aggregated CSV loaded with 5257 rows.
# 2025-04-23 16:40:12,553 - INFO - Consensus mapping created successfully.
# 2025-04-23 16:40:12,554 - INFO - Updating spectral data with consensus ratings.
# 2025-04-23 16:40:12,555 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.05.2018_21_32_28; set to None.
# 2025-04-23 16:40:12,556 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.28.2018_15_33_28; set to None.
# 2025-04-23 16:40:12,557 - WARNING - No consensus rating found for Unique ID DOSEESC_JH02_06.18.2018_18_33_19; set to None.
# 2025-04-23 16:40:12,557 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.28.2018_14_30_29; set to None.
# 2025-04-23 16:40:12,558 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.05.2018_12_31_29; set to None.
# 2025-04-23 16:40:12,559 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.05.2018_22_34_26; set to None.
# 2025-04-23 16:40:12,559 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.05.2018_14_36_26; set to None.
# 2025-04-23 16:40:12,560 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.28.2018_13_34_25; set to None.
# 2025-04-23 16:40:12,561 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.05.2018_12_33_26; set to None.
# 2025-04-23 16:40:12,562 - WARNING - No consensus rating found for Unique ID DOSEESC_JH02_06.18.2018_10_36_16; set to None.
# 2025-04-23 16:40:12,562 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.05.2018_14_29_28; set to None.
# 2025-04-23 16:40:12,563 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.28.2018_20_32_27; set to None.
# 2025-04-23 16:40:12,564 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.28.2018_14_37_31; set to None.
# 2025-04-23 16:40:12,564 - WARNING - No consensus rating found for Unique ID DOSEESC_JH02_05.22.2018_9_31_19; set to None.
# 2025-04-23 16:40:12,565 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.05.2018_10_35_22; set to None.
# 2025-04-23 16:40:12,566 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.28.2018_10_34_21; set to None.
# 2025-04-23 16:40:12,567 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.28.2018_13_34_29; set to None.
# 2025-04-23 16:40:12,569 - WARNING - No consensus rating found for Unique ID DOSEESC_JH02_06.18.2018_10_37_18; set to None.
# 2025-04-23 16:40:12,570 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.05.2018_13_30_26; set to None.
# 2025-04-23 16:40:12,571 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.28.2018_12_39_24; set to None.
# 2025-04-23 16:40:12,572 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.05.2018_14_34_26; set to None.
# 2025-04-23 16:40:12,573 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.28.2018_12_42_22; set to None.
# 2025-04-23 16:40:12,574 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.28.2018_14_38_29; set to None.
# 2025-04-23 16:40:12,575 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.28.2018_14_33_25; set to None.
# 2025-04-23 16:40:12,576 - WARNING - No consensus rating found for Unique ID DOSEESC_UM03_02.05.2018
# 2025-04-23 16:40:12,742 - INFO - --------------------------------------------------
# 2025-04-23 16:40:12,744 - INFO - Unique ID: DOSEESC_EM12_03.07.2019_12_36_40
# 2025-04-23 16:40:12,744 - INFO - Spectral Data Consensus Rating: Unacceptable
# 2025-04-23 16:40:12,745 - INFO - Aggregated CSV Row:
# 2025-04-23 16:40:12,748 - INFO -                        unique_id     rating_1     rating_2     rating_3    consensus                                             raters
# DOSEESC_EM12_03.07.2019_12_36_40 Unacceptable Unacceptable Unacceptable Unacceptable ['Andrew Maudsley', 'Eric Mellon', 'Hyunsuk Shim']
# 2025-04-23 16:40:12,749 - INFO - --------------------------------------------------
# 2025-04-23 16:40:12,751 - INFO - Unique ID: DOSEESC_JH10_12.05.2018_18_32_44
# 2025-04-23 16:40:12,752 - INFO - Spectral Data Consensus Rating: Acceptable
# 2025-04-23 16:40:12,753 - INFO - Aggregated CSV Row:
# 2025-04-23 16:40:12,756 - INFO -                        unique_id     rating_1   rating_2   rating_3  consensus                                             raters
# DOSEESC_JH10_12.05.2018_18_32_44 Unacceptable Acceptable Acceptable Acceptable ['Andrew Maudsley', 'Eric Mellon', 'Hyunsuk Shim']
# 2025-04-23 16:40:12,756 - INFO - --------------------------------------------------
# 2025-04-23 16:40:12,758 - INFO - Unique ID: DOSEESC_EM01_10.16.2017_14_33_19
# 2025-04-23 16:40:12,759 - INFO - Spectral Data Consensus Rating: Unacceptable
# 2025-04-23 16:40:12,760 - INFO - Aggregated CSV Row:
# 2025-04-23 16:40:12,762 - INFO -                        unique_id     rating_1     rating_2     rating_3    consensus                                           raters
# DOSEESC_EM01_10.16.2017_14_33_19 Unacceptable Unacceptable Unacceptable Unacceptable ['Harish Poptani', 'Hui-Kuo Shu', 'Brian Soher']
# 2025-04-23 16:40:12,762 - INFO - --------------------------------------------------
# 2025-04-23 16:40:12,764 - INFO - Unique ID: DOSEESC_EM04_02.07.2018_13_31_18
# 2025-04-23 16:40:12,764 - INFO - Spectral Data Consensus Rating: Acceptable
# 2025-04-23 16:40:12,765 - INFO - Aggregated CSV Row:
# 2025-04-23 16:40:12,768 - INFO -                        unique_id   rating_1   rating_2   rating_3  consensus                                                 raters
# DOSEESC_EM04_02.07.2018_13_31_18 Acceptable Acceptable Acceptable Acceptable ['Sulaiman Sheriff', 'Hyunsuk Shim', 'Brent Weinberg']
# 2025-04-23 16:40:12,768 - INFO - --------------------------------------------------
# 2025-04-23 16:40:12,770 - INFO - Unique ID: DOSEESC_EM15_06.11.2019_16_36_45
# 2025-04-23 16:40:12,771 - INFO - Spectral Data Consensus Rating: Acceptable
# 2025-04-23 16:40:12,772 - INFO - Aggregated CSV Row:
# 2025-04-23 16:40:12,774 - INFO -                        unique_id   rating_1   rating_2   rating_3  consensus                                             raters
# DOSEESC_EM15_06.11.2019_16_36_45 Acceptable Acceptable Acceptable Acceptable ['Andrew Maudsley', 'Eric Mellon', 'Hyunsuk Shim']
# 2025-04-23 16:40:12,775 - INFO - --------------------------------------------------
# 2025-04-23 16:40:12,777 - INFO - Unique ID: rGBM_006_08_01_2023_08.01.2023_21_36_26
# 2025-04-23 16:40:12,777 - INFO - Spectral Data Consensus Rating: Acceptable
# 2025-04-23 16:40:12,778 - INFO - Aggregated CSV Row:
# 2025-04-23 16:40:12,780 - INFO -                               unique_id   rating_1   rating_2   rating_3  consensus                                                 raters
# rGBM_006_08_01_2023_08.01.2023_21_36_26 Acceptable Acceptable Acceptable Acceptable ['Sulaiman Sheriff', 'Hyunsuk Shim', 'Brent Weinberg']
# 2025-04-23 16:40:12,781 - INFO - --------------------------------------------------
# 2025-04-23 16:40:12,782 - INFO - Unique ID: DOSEESC_EM11_01.03.2019_21_31_35
# 2025-04-23 16:40:12,783 - INFO - Spectral Data Consensus Rating: Acceptable
# 2025-04-23 16:40:12,784 - INFO - Aggregated CSV Row:
# 2025-04-23 16:40:12,786 - INFO -                        unique_id   rating_1   rating_2   rating_3  consensus                                           raters
# DOSEESC_EM11_01.03.2019_21_31_35 Acceptable Acceptable Acceptable Acceptable ['Harish Poptani', 'Hui-Kuo Shu', 'Brian Soher']
# 2025-04-23 16:40:12,786 - INFO - --------------------------------------------------
# 2025-04-23 16:40:12,788 - INFO - Unique ID: DOSEESC_UM04_03.28.2018_21_25_25
# 2025-04-23 16:40:12,789 - INFO - Spectral Data Consensus Rating: Acceptable
# 2025-04-23 16:40:12,790 - INFO - Aggregated CSV Row:
# 2025-04-23 16:40:12,791 - INFO -                        unique_id   rating_1   rating_2   rating_3  consensus                                           raters
# DOSEESC_UM04_03.28.2018_21_25_25 Acceptable Acceptable Acceptable Acceptable ['Harish Poptani', 'Hui-Kuo Shu', 'Brian Soher']
# 2025-04-23 16:40:12,792 - INFO - --------------------------------------------------
# 2025-04-23 16:40:12,793 - INFO - Unique ID: DOSEESC_UM16_11.14.2018_15_37_32
# 2025-04-23 16:40:12,794 - INFO - Spectral Data Consensus Rating: Acceptable
# 2025-04-23 16:40:12,795 - INFO - Aggregated CSV Row:
# 2025-04-23 16:40:12,797 - INFO -                        unique_id   rating_1   rating_2   rating_3  consensus                                                 raters
# DOSEESC_UM16_11.14.2018_15_37_32 Acceptable Acceptable Acceptable Acceptable ['Sulaiman Sheriff', 'Hyunsuk Shim', 'Brent Weinberg']
# 2025-04-23 16:40:12,798 - INFO - --------------------------------------------------
# 2025-04-23 16:40:12,809 - INFO - Reserved 942 / 5464 entries (17.2%) for the test set.

# %%
timestamp = dt.datetime.now().strftime("%Y%m%d_%H%M")

with open(output_dir / f"spectral_train_{timestamp}.pkl", "wb") as f:
    pickle.dump(train_data, f)

with open(output_dir / f"spectral_test_{timestamp}.pkl",  "wb") as f:
    pickle.dump(test_data, f)

logging.info("Train/test pickles written successfully")
# Out:
# 2025-04-23 16:40:15,943 - INFO - Train/test pickles written successfully
